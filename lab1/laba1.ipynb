# %% [markdown]
# # Дисциплина: Методы машинного обучения
# # Лабораторная работа №1 "Создание "истории о данных" (Data Storytelling)"
# # Выполнил: Грунин Н. С. ИУ5-24М

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.impute import MissingIndicator
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from IPython.display import Image
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
data = pd.read_csv('laptop.csv')
data.head()
# Out:
#    Unnamed: 0 Brand     Model  Series Processor Processor_Gen  RAM  \
# 0           0  DELL  Inspiron     NaN        i3          11th  8.0
# 1           1  DELL    Vostro     NaN        i5          11th  8.0
# 2           2  ASUS  VivoBook      15        i3          10th  8.0
# 3           3  DELL  Inspiron     NaN        i3          11th  8.0
# 4           4  ASUS       TUF  Gaming        i5          10th  8.0
#
#   Hard_Disk_Capacity               OS  Rating  Price
# 0           1 TB HDD  Windows 11 Home     3.7  39040
# 1           1 TB HDD  Windows 10 Home     3.6  50840
# 2         512 GB SSD  Windows 11 Home     4.3  37940
# 3           1 TB HDD       256 GB SSD     4.4  44440
# 4         512 GB SSD  Windows 10 Home     4.5  57940

# %%
data.dtypes
# Out:
# Unnamed: 0              int64
# Brand                  object
# Model                  object
# Series                 object
# Processor              object
# Processor_Gen          object
# RAM                   float64
# Hard_Disk_Capacity     object
# OS                     object
# Rating                float64
# Price                   int64
# dtype: object

# %%
Рассмотрим распределение рейтинга ноутбуков

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.kdeplot(data=data, x="Rating")
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Density'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.violinplot(x='Brand', y='RAM', data=data)
# Out:
# <AxesSubplot:xlabel='Brand', ylabel='RAM'>

# %%
Можем сделать вывод что самой большой оперативной памятью обладает ноутбук MSI

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.histplot(data['Processor'], discrete=True)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='Count'>

# %% [markdown]
# Можем сделать вывод что самый попоулярный процессор Intel i3

# %%
sns.kdeplot(data=data, x="Rating", y="Price")
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Price'>

# %%
sns.scatterplot(x='Processor', y='Price', data=data)
# Out:
# <AxesSubplot:xlabel='Processor', ylabel='Price'>

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(data.corr(method='pearson'), annot=True, fmt='.2f')
fig.suptitle('Корреляционные матрицы')
# Out:
# Text(0.5, 0.98, 'Корреляционные матрицы')

# %%
sns.pairplot(data)
plt.show()
